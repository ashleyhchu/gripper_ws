# %% [markdown]
# # Content
# 1. [Import dataSet](#1-Import-dataSet)
# 2. [Glance at data](#2.-Glance-at-data)
#     - [2.1 Plot all Features](#2.1-Plot-all-Features)
#         - Scatter Plot
#         - Scatter Plot Matrix
#         - Plot Line Graphic
#     - [2.2 Plot two Features](#2.2-Plot-two-Features)
#     - [2.3 Plot PCA 2-components](#2.3-Plot-PCA-2-components)
# 3. [Machine Learning](#3.-Machine-Learning)
#     - [3.1 Splitting Train/Test Dataset](#3.1-Splitting-Train/Test-Dataset)
#     - [3.2 Train a SVM Model](#3.2-Train-a-SVM-Model)
#     - [3.3 Evaluation](#3.3-Evaluation)
# 4. [Plotting decision regions](#4.-Plotting-decision-regions)
#     - [4.1 Plotting decision regions (2 PCA)](#4.3-Plotting-decision-regions-(2-PCA))
#     - [4.2 Plotting decision regions (9 Features)](#4.1-Plotting-decision-regions-(9-Features))
#     - [4.3 Plotting decision regions (2 Features)](#4.2-Plotting-decision-regions-(2-Features))
#     - [4.4 Plotting decision regions (2 Features showing test data)](#4.3-Plotting-decision-regions-(2-Features-showing-test-data))

# %% [markdown]
# ## 1 Import dataSet

# %%
# !pip install ipynb
from ipynb.fs.full.ml_svm_dataset import *

# %%
ds
# Out:
#       Red  Green  Blue     W1   Pot1     W2   Pot2     W3   Pot3  Fruit
# 0   107.0   82.0  63.0    0.0   76.0    0.0   76.0    0.0   76.0    0.0
# 1   106.0   82.0  63.0   11.5   77.0   32.5   77.0   26.0   77.0    0.0
# 2   108.0   80.0  62.0    0.0   80.5    0.0   80.5    0.0   80.5    0.0
# 3   108.0   81.0  63.0    0.0   75.5    0.0   75.5    7.5   75.5    0.0
# 4   109.0   80.0  62.0    1.0   78.0   15.5   78.0    0.0   78.0    0.0
# ..    ...    ...   ...    ...    ...    ...    ...    ...    ...    ...
# 9   102.0   82.0  65.0   62.0  190.5  199.0  190.5   75.0  190.5    4.0
# 10  104.0   81.0  65.0  133.5  152.5   20.0  152.5   77.5  152.5    4.0
# 11  102.0   82.0  65.0   88.0  245.0  132.0  245.0  148.5  245.0    4.0
# 12  104.0   81.0  64.0   64.5  154.5   69.0  154.5   63.0  154.5    4.0
# 13  103.0   82.0  65.0   58.0  153.0   80.0  153.0   79.0  153.0    4.0
#
# [192 rows x 10 columns]

# %%
X = ds.drop('Fruit', axis=1)
y = ds['Fruit']
y = y.to_numpy(dtype='int')
print('Class labels:', np.unique(y))
# Out:
# Class labels: [0 1 2 3 4]

# %% [markdown]
# ## 2. Glance at data

# %% [markdown]
# ### 2.1 Plot all Features

# %%
# Scatter Plot
import matplotlib.pyplot as plt
plt.figure(figsize=(9,6))
aaa = pd.melt(ds)
# sns.scatterplot(data=aaa, x="variable", y="value")

# %%
# Scatter Plot Matrix
import seaborn as sns
# sns.pairplot(ds)

# %%
# Plot Line Graphic
# print(len(ds))
plt.figure(figsize=(20,10))
x = np.linspace(0, len(ds), len(ds))
y_feature = ds.loc[:,'Red':'Pot3']
# plt.plot(x,y_feature,'-o')
# plt.show()

# %% [markdown]
# ### 2.2 Plot two Features

# %%
import seaborn as sns; sns.set(font_scale=1.2)
sns.lmplot('Red', 'W1', data=ds, hue='Fruit',
           palette='Set1', fit_reg=False, scatter_kws={"s": 20})

# %% [markdown]
# ### 2.3 Plot PCA 2-components

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 2)
X_pca = pca.fit_transform(X)
X_pca.shape
# Out:
# (192, 2)

# %%
plt.scatter(X_pca[:, 0], X_pca[:, 1], alpha=0.5)

plt.xlabel('PC 1')
plt.ylabel('PC 2')
plt.grid(True)
plt.show()

# %%
pca.explained_variance_ratio_
# Out:
# array([0.76281177, 0.12278493])

# %%
plt.bar(range(0, 1), pca.explained_variance_ratio_, alpha=0.5, align='center')
plt.step(range(0, 2), np.cumsum(pca.explained_variance_ratio_), where='mid')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal components')
plt.grid(True)

plt.show()

# %% [markdown]
# ## 3. Machine Learning

# %% [markdown]
# ### 3.1 Splitting Train/Test Dataset

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)

# %%
# Standardizing the features:
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

# %% [markdown]
# ### 3.2 Train a SVM Model

# %%
from sklearn import svm

svmClf = svm.SVC(C=1, kernel='linear', gamma='auto', random_state=1)
svmClf.fit(X_train_std, y_train)
# Out:
# SVC(C=1, gamma='auto', kernel='linear', random_state=1)

# %%
y_pred = svmClf.predict(X_test_std)
y_pred
# Out:
# array([4, 3, 1, 3, 1, 2, 1, 1, 0, 0, 2, 1, 1, 2, 0, 2, 0, 1, 2, 1, 1, 1,
#        2, 3, 1, 0, 0, 3, 0, 2, 0, 0, 4, 1, 2, 1, 3, 1, 0])

# %%
misclass = (y_test != y_pred).sum()
print('Misclassified examples: %d' % misclass)
# Out:
# Misclassified examples: 2

# %%
score = svmClf.score(X_test_std, y_test)
print('Accuracy: %.3f' % score)
# Out:
# Accuracy: 0.949

# %% [markdown]
# ### 3.3 Evaluation

# %%
from sklearn.metrics import accuracy_score

acc = accuracy_score(y_test, y_pred)
print('Accuracy: %.3f' % acc)
# Out:
# Accuracy: 0.949

# %% [markdown]
# ## 4. Plotting decision regions

# %% [markdown]
# ### 4.1 Plotting decision regions (2 PCA)

# %%
from mlxtend.plotting import plot_decision_regions

X_train_std_pca = pca.fit_transform(X_train_std)
pcaClf = svm.SVC(C=1, kernel='linear', gamma='auto', random_state=1)
pcaClf.fit(X_train_std_pca, y_train)

plt.figure(figsize=(10,6))
plot_decision_regions(X_train_std_pca, y_train, clf=pcaClf, legend=1)
plt.xlabel('PC 1 [standardized]')
plt.ylabel('PC 2 [standardized]')
plt.title('Soft-margin SVM classifier')
# Out:
# Text(0.5, 1.0, 'Soft-margin SVM classifier')

# %% [markdown]
# ### 4.2 Plotting decision regions (9 Features)

# %%
X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))
X_combined_std.shape
# Out:
# (192, 9)

# %%
value=0
width=9

plt.figure(figsize=(10,6))
plot_decision_regions(X_combined_std, y_combined, clf=svmClf, 
                     filler_feature_values={2:value, 3:value, 4:value, 5: value, 6:value, 7:value, 8:value},
                     filler_feature_ranges={2:width, 3:width, 4:width, 5: width, 6:width, 7:width, 8:width},
                     legend=1)
plt.xlabel('Red [standardized]')
plt.ylabel('Weight on Finger1 [standardized]')
plt.title('Soft-margin SVM classifier')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.3 Plotting decision regions (2 Features)

# %%
X_train_std_2fea = X_train_std[:,[0,3]]

twofeaClf = svm.SVC(C=1, kernel='linear', gamma='auto', random_state=1)
twofeaClf.fit(X_train_std_2fea, y_train)
# Out:
# SVC(C=1, gamma='auto', kernel='linear', random_state=1)

# %%
X_combined_std_2fea = X_combined_std[:,[0,3]]
X_combined_std_2fea.shape
# Out:
# (192, 2)

# %%
plt.figure(figsize=(10,6))
plot_decision_regions(X_combined_std_2fea, y_combined, clf=twofeaClf,legend=1)
plt.xlabel('Red [standardized]')
plt.ylabel('Weight on Finger1 [standardized]')
plt.title('Soft-margin SVM classifier')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.4 Plotting decision regions (2 Features showing test data)

# %%
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt


def plot_decision_regions(X, y, classifier, test_idx=None, resolution=0.02):

    # setup marker generator and color map
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])

    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.3, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], 
                    y=X[y == cl, 1],
                    alpha=0.5, 
                    c=colors[idx],
                    marker=markers[idx], 
                    label=cl, 
                    edgecolor='black')

    # highlight test examples
    if test_idx:
        # plot all examples
        X_test, y_test = X[test_idx, :], y[test_idx]

        plt.scatter(X_test[:, 0],
                    X_test[:, 1],
                    c='',
                    edgecolor='black',
                    alpha=1.0,
                    linewidth=1,
                    marker='o',
                    s=100, 
                    label='test set')

# %%
plt.figure(figsize=(10,6))
plot_decision_regions(X_combined_std_2fea, y_combined, twofeaClf, test_idx=range(153, 192))
plt.xlabel('Red [standardized]')
plt.ylabel('Weight on Finger1 [standardized]')
plt.title('Soft-margin SVM classifier')
plt.legend(loc='lower left')
plt.show()
# Out:
# <ipython-input-50-c6ec46c3c7af>:37: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   plt.scatter(X_test[:, 0],

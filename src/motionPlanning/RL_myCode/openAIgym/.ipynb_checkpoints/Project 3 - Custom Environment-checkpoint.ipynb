# %%
#https://sourceforge.net/projects/swig/files/swigwin/swigwin-4.0.2/swigwin-4.0.2.zip/download?use_mirror=ixpeering

# %% [markdown]
# # 1. Import Dependencies

# %%
import gym 
from gym import Env
from gym.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete 
import numpy as np
import random
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # 2. Types of Spaces

# %%
Discrete(3)
# Out:
# Discrete(3)

# %%
Box(0,1,shape=(3,3)).sample()
# Out:
# array([[0.6239138 , 0.93883914, 0.6137536 ],
#        [0.9336845 , 0.68289065, 0.67978954],
#        [0.42686203, 0.2064635 , 0.59755194]], dtype=float32)

# %%
Box(0,255,shape=(3,3), dtype=int).sample()
# Out:
# array([[ 48, 141, 181],
#        [ 94, 149,  59],
#        [231,  78, 164]])

# %%
Tuple((Discrete(2), Box(0,100, shape=(1,)))).sample()
# Out:
# (1, array([8.713729], dtype=float32))

# %%
Dict({'height':Discrete(2), "speed":Box(0,100, shape=(1,))}).sample()
# Out:
# OrderedDict([('height', 1), ('speed', array([73.191124], dtype=float32))])

# %%
MultiBinary(4).sample()
# Out:
# array([1, 0, 0, 1], dtype=int8)

# %%
MultiDiscrete([5,2,2]).sample()
# Out:
# array([4, 1, 0])

# %% [markdown]
# # 3. Building an Environment

# %%
class ShowerEnv(Env):
    def __init__(self):
        # Actions we can take, down, stay, up
        self.action_space = Discrete(3)
        # Temperature array
        self.observation_space = Box(low=np.array([0]), high=np.array([100]))
        # Set start temp
        self.state = 38 + random.randint(-3,3)
        # Set shower length
        self.shower_length = 60
        
    def step(self, action):
        # Apply action
        # 0 -1 = -1 temperature
        # 1 -1 = 0 
        # 2 -1 = 1 temperature 
        self.state += action -1 
        # Reduce shower length by 1 second
        self.shower_length -= 1 
        
        # Calculate reward
        if self.state >=37 and self.state <=39: 
            reward =1 
        else: 
            reward = -1 
        
        # Check if shower is done
        if self.shower_length <= 0: 
            done = True
        else:
            done = False
        
        # Apply temperature noise
        #self.state += random.randint(-1,1)
        # Set placeholder for info
        info = {}
        
        # Return step information
        return self.state, reward, done, info

    def render(self):
        # Implement viz
        pass
    
    def reset(self):
        # Reset shower temperature
        self.state = np.array([38 + random.randint(-3,3)]).astype(float)
        # Reset shower time
        self.shower_length = 60 
        return self.state

# %%
env=ShowerEnv()
# Out:
# /home/ash/gripper_ws/src/motionPlanning/gym/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
env.observation_space.sample()
# Out:
# array([19.784248], dtype=float32)

# %%
env.reset()
# Out:
# array([41.])

# %%
from stable_baselines3.common.env_checker import check_env

# %%
check_env(env, warn=True)

# %% [markdown]
# # 4. Test Environment

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:-44
# Episode:2 Score:-44
# Episode:3 Score:-16
# Episode:4 Score:-54
# Episode:5 Score:-58

# %%
env.close()

# %% [markdown]
# # 5. Train Model

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=400000)
# Out:
# /home/ash/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ash/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ash/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ash/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ash/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ash/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Logging to Training/Logs/PPO_9
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | -25.4    |
# | time/              |          |
# |    fps             | 1156     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -25.4       |
# | time/                   |             |
# |    fps                  | 1134        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007987254 |
# |    clip_fraction        | 0.0953      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.000877   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.2        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00593    |
# |    value_loss           | 56.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -24.9       |
# | time/                   |             |
# |    fps                  | 1109        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012715337 |
# |    clip_fraction        | 0.0638      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.00612    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00593    |
# |    value_loss           | 57.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -23.8        |
# | time/                   |              |
# |    fps                  | 1091         |
# |    iterations           | 4            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0085535245 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.00291     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.2         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00262     |
# |    value_loss           | 60.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -25.6        |
# | time/                   |              |
# |    fps                  | 1120         |
# |    iterations           | 5            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0027049435 |
# |    clip_fraction        | 0.0531       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -2.5e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.1         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0033      |
# |    value_loss           | 64.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -24.6       |
# | time/                   |             |
# |    fps                  | 1163        |
# |    iterations           | 6           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.005413619 |
# |    clip_fraction        | 0.0586      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.000252   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.2        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00255    |
# |    value_loss           | 68.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -25.9       |
# | time/                   |             |
# |    fps                  | 1174        |
# |    iterations           | 7           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.001977848 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -3.17e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.9        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.000753   |
# |    value_loss           | 57.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -23.4        |
# | time/                   |              |
# |    fps                  | 1168         |
# |    iterations           | 8            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0075962157 |
# |    clip_fraction        | 0.0386       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -1.62e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.9         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0026      |
# |    value_loss           | 64.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -25.1       |
# | time/                   |             |
# |    fps                  | 1164        |
# |    iterations           | 9           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010580332 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -7.27e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.1        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 76.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -19.3       |
# | time/                   |             |
# |    fps                  | 1172        |
# |    iterations           | 10          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.011655016 |
# |    clip_fraction        | 0.0511      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -2.36e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.4        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00482    |
# |    value_loss           | 66.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -19.3       |
# | time/                   |             |
# |    fps                  | 1175        |
# |    iterations           | 11          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.005113082 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -4.78e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.5        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00218    |
# |    value_loss           | 54.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -14.1       |
# | time/                   |             |
# |    fps                  | 1186        |
# |    iterations           | 12          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009460166 |
# |    clip_fraction        | 0.0902      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.000545    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.7        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00675    |
# |    value_loss           | 61.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -12.6       |
# | time/                   |             |
# |    fps                  | 1198        |
# |    iterations           | 13          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008691329 |
# |    clip_fraction        | 0.0935      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 6.6e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.5        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00409    |
# |    value_loss           | 53.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | -7.44      |
# | time/                   |            |
# |    fps                  | 1208       |
# |    iterations           | 14         |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.01476585 |
# |    clip_fraction        | 0.223      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.05      |
# |    explained_variance   | 0.00115    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 25.8       |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.019     |
# |    value_loss           | 52.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -10.6       |
# | time/                   |             |
# |    fps                  | 1210        |
# |    iterations           | 15          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007976043 |
# |    clip_fraction        | 0.0232      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.00645     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.6        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00317    |
# |    value_loss           | 47.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -5.66        |
# | time/                   |              |
# |    fps                  | 1205         |
# |    iterations           | 16           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0131462235 |
# |    clip_fraction        | 0.21         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.0338      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.8         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0227      |
# |    value_loss           | 46.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -3.64       |
# | time/                   |             |
# |    fps                  | 1209        |
# |    iterations           | 17          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.005781442 |
# |    clip_fraction        | 0.0839      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 6.38e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.6        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00493    |
# |    value_loss           | 37.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 5.04        |
# | time/                   |             |
# |    fps                  | 1207        |
# |    iterations           | 18          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.011899877 |
# |    clip_fraction        | 0.0884      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -0.00182    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.4        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00902    |
# |    value_loss           | 38.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 10.5        |
# | time/                   |             |
# |    fps                  | 1207        |
# |    iterations           | 19          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.010991065 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.00148     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.4        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 30.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 20.8        |
# | time/                   |             |
# |    fps                  | 1214        |
# |    iterations           | 20          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.012361996 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | -0.00119    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.3        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00834    |
# |    value_loss           | 27          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 24.9       |
# | time/                   |            |
# |    fps                  | 1223       |
# |    iterations           | 21         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.00932561 |
# |    clip_fraction        | 0.175      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | 0.000489   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 15.7       |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00119   |
# |    value_loss           | 30.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 27.9        |
# | time/                   |             |
# |    fps                  | 1231        |
# |    iterations           | 22          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008801088 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.981      |
# |    explained_variance   | -8.65e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14          |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.00453     |
# |    value_loss           | 33.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 29.4        |
# | time/                   |             |
# |    fps                  | 1240        |
# |    iterations           | 23          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.011220275 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.96       |
# |    explained_variance   | -9.91e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.5        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00108    |
# |    value_loss           | 35.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 31.4        |
# | time/                   |             |
# |    fps                  | 1249        |
# |    iterations           | 24          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.029447664 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.937      |
# |    explained_variance   | 6.5e-06     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.6        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.0073      |
# |    value_loss           | 36.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 30.9        |
# | time/                   |             |
# |    fps                  | 1258        |
# |    iterations           | 25          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.012497885 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.943      |
# |    explained_variance   | 0.000126    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.4        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00452    |
# |    value_loss           | 43          |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 60       |
# |    ep_rew_mean          | 31.6     |
# | time/                   |          |
# |    fps                  | 1266     |
# |    iterations           | 26       |
# |    time_elapsed         | 42       |
# |    total_timesteps      | 53248    |
# | train/                  |          |
# |    approx_kl            | 0.013313 |
# |    clip_fraction        | 0.206    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.934   |
# |    explained_variance   | 0.000144 |
# |    learning_rate        | 0.0003   |
# |    loss                 | 22.5     |
# |    n_updates            | 250      |
# |    policy_gradient_loss | -0.00975 |
# |    value_loss           | 43.8     |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 34.2        |
# | time/                   |             |
# |    fps                  | 1273        |
# |    iterations           | 27          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.010273403 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.917      |
# |    explained_variance   | 1.93e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.7        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.00331     |
# |    value_loss           | 43.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 37.1        |
# | time/                   |             |
# |    fps                  | 1279        |
# |    iterations           | 28          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.016995393 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.901      |
# |    explained_variance   | 5.6e-06     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.9        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.00793     |
# |    value_loss           | 44.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 39.5        |
# | time/                   |             |
# |    fps                  | 1278        |
# |    iterations           | 29          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.015106081 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.915      |
# |    explained_variance   | 4.69e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.8        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00239    |
# |    value_loss           | 58.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 42.2       |
# | time/                   |            |
# |    fps                  | 1272       |
# |    iterations           | 30         |
# |    time_elapsed         | 48         |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.02643878 |
# |    clip_fraction        | 0.282      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.894     |
# |    explained_variance   | -1.29e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 34.1       |
# |    n_updates            | 290        |
# |    policy_gradient_loss | 0.0185     |
# |    value_loss           | 59.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 42.8        |
# | time/                   |             |
# |    fps                  | 1266        |
# |    iterations           | 31          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.023119338 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.911      |
# |    explained_variance   | 2.15e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.7        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.0143      |
# |    value_loss           | 67.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 42.6        |
# | time/                   |             |
# |    fps                  | 1264        |
# |    iterations           | 32          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009534743 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.919      |
# |    explained_variance   | 1.53e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.5        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.00438     |
# |    value_loss           | 63          |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 60        |
# |    ep_rew_mean          | 43.4      |
# | time/                   |           |
# |    fps                  | 1261      |
# |    iterations           | 33        |
# |    time_elapsed         | 53        |
# |    total_timesteps      | 67584     |
# | train/                  |           |
# |    approx_kl            | 0.0328016 |
# |    clip_fraction        | 0.244     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.887    |
# |    explained_variance   | 6.5e-06   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 34.6      |
# |    n_updates            | 320       |
# |    policy_gradient_loss | 0.00992   |
# |    value_loss           | 64.7      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 43.9        |
# | time/                   |             |
# |    fps                  | 1256        |
# |    iterations           | 34          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.033799846 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.883      |
# |    explained_variance   | 4.89e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.2        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.00923     |
# |    value_loss           | 68.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 44.4        |
# | time/                   |             |
# |    fps                  | 1253        |
# |    iterations           | 35          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.023151144 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.876      |
# |    explained_variance   | 6.2e-06     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.3        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.00449     |
# |    value_loss           | 73.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 41.9        |
# | time/                   |             |
# |    fps                  | 1251        |
# |    iterations           | 36          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.009954752 |
# |    clip_fraction        | 0.313       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.875      |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32          |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.0195      |
# |    value_loss           | 70.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 43.7        |
# | time/                   |             |
# |    fps                  | 1252        |
# |    iterations           | 37          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.012570528 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.877      |
# |    explained_variance   | -8.7e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.8        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00713     |
# |    value_loss           | 72          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 45.1        |
# | time/                   |             |
# |    fps                  | 1252        |
# |    iterations           | 38          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.016323334 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.888      |
# |    explained_variance   | 8.34e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.4        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00908     |
# |    value_loss           | 72.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 48.5         |
# | time/                   |              |
# |    fps                  | 1254         |
# |    iterations           | 39           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0074790707 |
# |    clip_fraction        | 0.208        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.874       |
# |    explained_variance   | 2.21e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.3         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | 0.00876      |
# |    value_loss           | 77           |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 48.1       |
# | time/                   |            |
# |    fps                  | 1256       |
# |    iterations           | 40         |
# |    time_elapsed         | 65         |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.02188387 |
# |    clip_fraction        | 0.24       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.863     |
# |    explained_variance   | -1.55e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 51.7       |
# |    n_updates            | 390        |
# |    policy_gradient_loss | 0.0117     |
# |    value_loss           | 80.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 48.2        |
# | time/                   |             |
# |    fps                  | 1258        |
# |    iterations           | 41          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.015976554 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.84       |
# |    explained_variance   | -1.91e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.9        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.011       |
# |    value_loss           | 83.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 48.8        |
# | time/                   |             |
# |    fps                  | 1258        |
# |    iterations           | 42          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.029728573 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.845      |
# |    explained_variance   | -8.34e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.4        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.0126      |
# |    value_loss           | 86.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47.1        |
# | time/                   |             |
# |    fps                  | 1260        |
# |    iterations           | 43          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.039696846 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.852      |
# |    explained_variance   | -7.15e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.4        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.0179      |
# |    value_loss           | 87.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 46.2        |
# | time/                   |             |
# |    fps                  | 1262        |
# |    iterations           | 44          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.006875787 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.858      |
# |    explained_variance   | 1.79e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.1        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.0109      |
# |    value_loss           | 81.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 46.1        |
# | time/                   |             |
# |    fps                  | 1263        |
# |    iterations           | 45          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.015735004 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.842      |
# |    explained_variance   | 1.79e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.7        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.0125      |
# |    value_loss           | 75.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49          |
# | time/                   |             |
# |    fps                  | 1264        |
# |    iterations           | 46          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.019151207 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.827      |
# |    explained_variance   | 5.19e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.5        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.0123      |
# |    value_loss           | 79.2        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 60        |
# |    ep_rew_mean          | 50.1      |
# | time/                   |           |
# |    fps                  | 1263      |
# |    iterations           | 47        |
# |    time_elapsed         | 76        |
# |    total_timesteps      | 96256     |
# | train/                  |           |
# |    approx_kl            | 0.0157264 |
# |    clip_fraction        | 0.243     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.812    |
# |    explained_variance   | 2.38e-07  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 47        |
# |    n_updates            | 460       |
# |    policy_gradient_loss | 0.0124    |
# |    value_loss           | 85.9      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 50.3        |
# | time/                   |             |
# |    fps                  | 1261        |
# |    iterations           | 48          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.027362151 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.768      |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.5        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.0195      |
# |    value_loss           | 85.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 50.8        |
# | time/                   |             |
# |    fps                  | 1265        |
# |    iterations           | 49          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.011741204 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.747      |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.2        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.0104      |
# |    value_loss           | 87          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 50.4       |
# | time/                   |            |
# |    fps                  | 1268       |
# |    iterations           | 50         |
# |    time_elapsed         | 80         |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.01675134 |
# |    clip_fraction        | 0.204      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.762     |
# |    explained_variance   | 2.38e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 53.2       |
# |    n_updates            | 490        |
# |    policy_gradient_loss | 0.00882    |
# |    value_loss           | 91.1       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 49.4         |
# | time/                   |              |
# |    fps                  | 1271         |
# |    iterations           | 51           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0118680075 |
# |    clip_fraction        | 0.212        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.762       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.9         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | 0.00981      |
# |    value_loss           | 89.1         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 46.3       |
# | time/                   |            |
# |    fps                  | 1272       |
# |    iterations           | 52         |
# |    time_elapsed         | 83         |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.09377755 |
# |    clip_fraction        | 0.311      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.757     |
# |    explained_variance   | -4.77e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 32         |
# |    n_updates            | 510        |
# |    policy_gradient_loss | 0.0232     |
# |    value_loss           | 86.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 43.3        |
# | time/                   |             |
# |    fps                  | 1276        |
# |    iterations           | 53          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.026174363 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.772      |
# |    explained_variance   | 9.54e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.8        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | 0.0122      |
# |    value_loss           | 79.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# ...
# |    policy_gradient_loss | 0.0187      |
# |    value_loss           | 100         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 48.7        |
# | time/                   |             |
# |    fps                  | 1349        |
# |    iterations           | 179         |
# |    time_elapsed         | 271         |
# |    total_timesteps      | 366592      |
# | train/                  |             |
# |    approx_kl            | 0.027411819 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.54       |
# |    explained_variance   | -8.11e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.5        |
# |    n_updates            | 1780        |
# |    policy_gradient_loss | 0.0213      |
# |    value_loss           | 99.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 37          |
# | time/                   |             |
# |    fps                  | 1348        |
# |    iterations           | 180         |
# |    time_elapsed         | 273         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.024796326 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.549      |
# |    explained_variance   | -8.58e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.2        |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | 0.0138      |
# |    value_loss           | 87.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 28.9        |
# | time/                   |             |
# |    fps                  | 1346        |
# |    iterations           | 181         |
# |    time_elapsed         | 275         |
# |    total_timesteps      | 370688      |
# | train/                  |             |
# |    approx_kl            | 0.024675475 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.565      |
# |    explained_variance   | -6.4e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.2        |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | 0.00291     |
# |    value_loss           | 60.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 31.2        |
# | time/                   |             |
# |    fps                  | 1345        |
# |    iterations           | 182         |
# |    time_elapsed         | 277         |
# |    total_timesteps      | 372736      |
# | train/                  |             |
# |    approx_kl            | 0.034282457 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.559      |
# |    explained_variance   | -0.000462   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27          |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | 0.00191     |
# |    value_loss           | 45.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 41.9        |
# | time/                   |             |
# |    fps                  | 1344        |
# |    iterations           | 183         |
# |    time_elapsed         | 278         |
# |    total_timesteps      | 374784      |
# | train/                  |             |
# |    approx_kl            | 0.030168805 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.547      |
# |    explained_variance   | -0.000126   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.3        |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | 0.00984     |
# |    value_loss           | 56.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 50         |
# | time/                   |            |
# |    fps                  | 1343       |
# |    iterations           | 184        |
# |    time_elapsed         | 280        |
# |    total_timesteps      | 376832     |
# | train/                  |            |
# |    approx_kl            | 0.06349167 |
# |    clip_fraction        | 0.213      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.536     |
# |    explained_variance   | -1.87e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 35.6       |
# |    n_updates            | 1830       |
# |    policy_gradient_loss | 0.0197     |
# |    value_loss           | 67.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 48.8        |
# | time/                   |             |
# |    fps                  | 1342        |
# |    iterations           | 185         |
# |    time_elapsed         | 282         |
# |    total_timesteps      | 378880      |
# | train/                  |             |
# |    approx_kl            | 0.026634619 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.556      |
# |    explained_variance   | -6.4e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.9        |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | 0.0175      |
# |    value_loss           | 76.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47          |
# | time/                   |             |
# |    fps                  | 1341        |
# |    iterations           | 186         |
# |    time_elapsed         | 283         |
# |    total_timesteps      | 380928      |
# | train/                  |             |
# |    approx_kl            | 0.014307056 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.563      |
# |    explained_variance   | -0.000133   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.8        |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | 0.0128      |
# |    value_loss           | 77.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 44.3        |
# | time/                   |             |
# |    fps                  | 1340        |
# |    iterations           | 187         |
# |    time_elapsed         | 285         |
# |    total_timesteps      | 382976      |
# | train/                  |             |
# |    approx_kl            | 0.008900364 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.567      |
# |    explained_variance   | 5.96e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.7        |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | 0.0151      |
# |    value_loss           | 76.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 46.4       |
# | time/                   |            |
# |    fps                  | 1338       |
# |    iterations           | 188        |
# |    time_elapsed         | 287        |
# |    total_timesteps      | 385024     |
# | train/                  |            |
# |    approx_kl            | 0.07789239 |
# |    clip_fraction        | 0.273      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.567     |
# |    explained_variance   | -0.000113  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 26.4       |
# |    n_updates            | 1870       |
# |    policy_gradient_loss | 0.021      |
# |    value_loss           | 75.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47.5        |
# | time/                   |             |
# |    fps                  | 1337        |
# |    iterations           | 189         |
# |    time_elapsed         | 289         |
# |    total_timesteps      | 387072      |
# | train/                  |             |
# |    approx_kl            | 0.008604344 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.559      |
# |    explained_variance   | -7.63e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42          |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | 0.0149      |
# |    value_loss           | 80.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47.7        |
# | time/                   |             |
# |    fps                  | 1336        |
# |    iterations           | 190         |
# |    time_elapsed         | 291         |
# |    total_timesteps      | 389120      |
# | train/                  |             |
# |    approx_kl            | 0.020795807 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.564      |
# |    explained_variance   | -9.87e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.4        |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | 0.0131      |
# |    value_loss           | 83.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47.5        |
# | time/                   |             |
# |    fps                  | 1336        |
# |    iterations           | 191         |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 391168      |
# | train/                  |             |
# |    approx_kl            | 0.016453711 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.562      |
# |    explained_variance   | -1.7e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.3        |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | 0.0153      |
# |    value_loss           | 77.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47.6        |
# | time/                   |             |
# |    fps                  | 1335        |
# |    iterations           | 192         |
# |    time_elapsed         | 294         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.021165574 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.554      |
# |    explained_variance   | -1.29e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.2        |
# |    n_updates            | 1910        |
# |    policy_gradient_loss | 0.0214      |
# |    value_loss           | 78          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 44.1        |
# | time/                   |             |
# |    fps                  | 1334        |
# |    iterations           | 193         |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 395264      |
# | train/                  |             |
# |    approx_kl            | 0.020676475 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.556      |
# |    explained_variance   | -2.86e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.3        |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | 0.0173      |
# |    value_loss           | 78.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 38.7        |
# | time/                   |             |
# |    fps                  | 1334        |
# |    iterations           | 194         |
# |    time_elapsed         | 297         |
# |    total_timesteps      | 397312      |
# | train/                  |             |
# |    approx_kl            | 0.016447991 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.56       |
# |    explained_variance   | -3.79e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.7        |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | 0.012       |
# |    value_loss           | 71.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 35.5        |
# | time/                   |             |
# |    fps                  | 1333        |
# |    iterations           | 195         |
# |    time_elapsed         | 299         |
# |    total_timesteps      | 399360      |
# | train/                  |             |
# |    approx_kl            | 0.013867104 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.564      |
# |    explained_variance   | 4.93e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.2        |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | 0.00624     |
# |    value_loss           | 58.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 35.6        |
# | time/                   |             |
# |    fps                  | 1332        |
# |    iterations           | 196         |
# |    time_elapsed         | 301         |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.015228326 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.553      |
# |    explained_variance   | 0.000106    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.1        |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | 0.0105      |
# |    value_loss           | 56.4        |
# -----------------------------------------

# %% [markdown]
# # 6. Save Model

# %%
shower_path = os.path.join('Training', 'Saved Models', 'Shower_Model_PPO')

# %%
model.save(shower_path)

# %%
del model

# %%
model = PPO.load(shower_path, env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=False)
# Out:
# /home/ash/anaconda3/envs/tensorflow1_14/lib/python3.6/site-packages/stable_baselines3/common/evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# (59.4, 0.9165151389911679)

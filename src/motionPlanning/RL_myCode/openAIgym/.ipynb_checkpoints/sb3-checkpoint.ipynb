# %% [markdown]
# ## 1. Import Dependencies

# %%
# !pip install stable-baselines3[extra]

# %%
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# ## 2.1 Load Environment

# %%
env_name = "CartPole-v0"

# %%
env = gym.make(env_name)

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:29.0
# Episode:2 Score:23.0
# Episode:3 Score:20.0
# Episode:4 Score:12.0
# Episode:5 Score:17.0

# %%
env.close()

# %%
episodes = 5
for episodes in range(1, episodes+1):
    print(episodes)

# %% [markdown]
# ## 2.2 Understanding The Environment

# %%
# 0-push cart to left, 1-push cart to the right
env.action_space.sample()
# Out:
# 1

# %%
env.action_space
# Out:
# Discrete(2)

# %%
env.reset()
# Out:
# array([0.04195113, 0.04148554, 0.00221219, 0.03054249])

# %%
# [cart position, cart velocity, pole angle, pole angular velocity]
env.observation_space.sample()
# Out:
# array([-4.51661539e+00, -2.01903315e+38,  1.05540805e-01, -5.17957624e+37],
#       dtype=float32)

# %%
env.observation_space
# Out:
# Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)

# %%
env.step(1)
# Out:
# (array([ 0.04278084,  0.23657569,  0.00282304, -0.26144165]), 1.0, False, {})

# %% [markdown]
# ## 3. Train an RL Model

# %%
env = gym.make(env_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose = 1)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 2807 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1785        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009380554 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.000414   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.68        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0181     |
# |    value_loss           | 53.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1638        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009748915 |
# |    clip_fraction        | 0.0689      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.0974      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.9        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0163     |
# |    value_loss           | 34          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1577        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009537595 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.629      |
# |    explained_variance   | 0.271       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.9        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0205     |
# |    value_loss           | 46.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1537        |
# |    iterations           | 5           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008243274 |
# |    clip_fraction        | 0.068       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.603      |
# |    explained_variance   | 0.328       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.3        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 57.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1512        |
# |    iterations           | 6           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011291418 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.591      |
# |    explained_variance   | 0.51        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.8        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0214     |
# |    value_loss           | 60.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1477        |
# |    iterations           | 7           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010216301 |
# |    clip_fraction        | 0.0924      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.59       |
# |    explained_variance   | 0.469       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.3        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 59.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1445         |
# |    iterations           | 8            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0031978595 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.596       |
# |    explained_variance   | 0.497        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.2         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00372     |
# |    value_loss           | 57.5         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1429        |
# |    iterations           | 9           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.003959203 |
# |    clip_fraction        | 0.0191      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.568      |
# |    explained_variance   | 0.236       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.1        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00404    |
# |    value_loss           | 98.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1420         |
# |    iterations           | 10           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0037991263 |
# |    clip_fraction        | 0.0422       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.585       |
# |    explained_variance   | 0.5          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.6         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00269     |
# |    value_loss           | 74.9         |
# ------------------------------------------

# %%
# PPO??

# %% [markdown]
# ## 4. Save and Reload Model

# %%
import os

# %%
reach_sitePPO_path = os.path.join('Training', 'Saved Models', 'PPO_model')

# %%
# PPO_path

# %%
model.save(PPO_path)

# %%
# del model

# %%
# model.learn(total_timesteps=1000)

# %%
model = PPO.load(PPO_path, env=env)

# %%
# model = PPO.load('PPO_model', env=env)

# %% [markdown]
# ## 5. Evaluation

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# /home/ash/anaconda3/envs/tensorflow1_14/lib/python3.6/site-packages/stable_baselines3/common/evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# (200.0, 0.0)

# %%
env.close()

# %% [markdown]
# ## 6. Test Model

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    env.render()
    if done: 
        print('info', info)
        break
# Out:
# info [{'TimeLimit.truncated': True, 'terminal_observation': array([ 0.91545118,  0.37534342, -0.0189362 ,  0.08869011])}]

# %%
env.close()

# %% [markdown]
# ## 7. Viewing Logs in Tensorboard

# %%
log_path = os.path.join('Training', 'Logs')
training_log_path = os.path.join(log_path, 'PPO_1')

# %%
training_log_path
# Out:
# 'Training/Logs/PPO_1'

# %%
# !tensorboard --logdir={training_log_path}
# Out:
# /home/ash/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ash/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ash/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ash/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ash/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ash/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.7.0 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %% [markdown]
# ## 8. Adding a callback to the training Stage

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold
import os

# %%
save_path = os.path.join('Training', 'Saved Models')
log_path = os.path.join('Training', 'Logs')

# %%
env = gym.make(env_name)
env = DummyVecEnv([lambda: env])

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=190, verbose=1)
eval_callback = EvalCallback(env, 
                             callback_on_new_best=stop_callback, 
                             eval_freq=10000, 
                             best_model_save_path=save_path, 
                             verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# /home/ash/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ash/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ash/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ash/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ash/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ash/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Logging to Training/Logs/PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 1327 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1354        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008443292 |
# |    clip_fraction        | 0.0837      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | -0.00451    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.3        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 60.6        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1371         |
# |    iterations           | 3            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0092364615 |
# |    clip_fraction        | 0.0583       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.668       |
# |    explained_variance   | 0.0532       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.78         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0173      |
# |    value_loss           | 39.8         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1385        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007968225 |
# |    clip_fraction        | 0.0838      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.635      |
# |    explained_variance   | 0.206       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.7        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0181     |
# |    value_loss           | 59.6        |
# -----------------------------------------
# /home/ash/anaconda3/envs/tensorflow1_14/lib/python3.6/site-packages/stable_baselines3/common/evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# Eval num_timesteps=10000, episode_reward=177.60 +/- 20.48
# Episode length: 177.60 +/- 20.48
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 178         |
# |    mean_reward          | 178         |
# | time/                   |             |
# |    total timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.006179693 |
# |    clip_fraction        | 0.0571      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.615      |
# |    explained_variance   | 0.247       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.7        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 64.6        |
# -----------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 1324  |
# |    iterations      | 5     |
# |    time_elapsed    | 7     |
# |    total_timesteps | 10240 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1339         |
# |    iterations           | 6            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0068314173 |
# |    clip_fraction        | 0.0423       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.605       |
# |    explained_variance   | 0.409        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.3         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0108      |
# |    value_loss           | 61.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1353         |
# |    iterations           | 7            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0042605945 |
# |    clip_fraction        | 0.0246       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.58        |
# |    explained_variance   | 0.453        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.1         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00583     |
# |    value_loss           | 70.8         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1360        |
# |    iterations           | 8           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006777905 |
# |    clip_fraction        | 0.0463      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.575      |
# |    explained_variance   | 0.725       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.84        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00618    |
# |    value_loss           | 44          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1361        |
# |    iterations           | 9           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.003019933 |
# |    clip_fraction        | 0.0254      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.543      |
# |    explained_variance   | 0.741       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.3        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00419    |
# |    value_loss           | 53.1        |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=159.20 +/- 18.06
# Episode length: 159.20 +/- 18.06
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 159          |
# |    mean_reward          | 159          |
# | time/                   |              |
# |    total timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0065795663 |
# |    clip_fraction        | 0.0477       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.551       |
# |    explained_variance   | 0.886        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.4         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0028      |
# |    value_loss           | 31.8         |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 1339  |
# |    iterations      | 10    |
# |    time_elapsed    | 15    |
# |    total_timesteps | 20480 |
# ------------------------------

# %%
model_path = os.path.join('Training', 'Saved Models', 'best_model')
model = PPO.load(model_path, env=env)

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# (179.4, 18.287700784953806)

# %%
env.close()

# %% [markdown]
# ## 9. Changing Policies

# %%
net_arch=[dict(pi=[128, 128, 128, 128], vf=[128, 128, 128, 128])]

# %%
model = PPO('MlpPolicy', env, verbose = 1, policy_kwargs={'net_arch': net_arch})
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 1849 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1227        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014892491 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | 0.000295    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.99        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0299     |
# |    value_loss           | 20.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1111        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.015437495 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.647      |
# |    explained_variance   | 0.424       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0319     |
# |    value_loss           | 26.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1050        |
# |    iterations           | 4           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015090286 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.603      |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21          |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0305     |
# |    value_loss           | 45.7        |
# -----------------------------------------
# Eval num_timesteps=9520, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 200        |
# |    mean_reward          | 200        |
# | time/                   |            |
# |    total timesteps      | 9520       |
# | train/                  |            |
# |    approx_kl            | 0.00841226 |
# |    clip_fraction        | 0.115      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.585     |
# |    explained_variance   | 0.497      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 19.7       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0196    |
# |    value_loss           | 48.7       |
# ----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 200.00  is above the threshold 190

# %% [markdown]
# ## 10. Using an Alternate Algorithm

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training/Logs/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.958    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 2828     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 89       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.91     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 4258     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 189      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.877    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 4938     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 259      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.837    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 5750     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 343      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.798    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 6189     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 426      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.724    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 7029     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 582      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.699    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 7071     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 634      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.666    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 7011     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 704      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.621    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 6856     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 797      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.588    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 6895     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 867      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.557    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 6888     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 932      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.493    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 7225     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1067     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.451    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 7369     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1155     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.417    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 7472     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1227     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.382    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 7570     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1302     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.34     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 7698     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1390     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.291    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 7843     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1492     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.2      |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 8151     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1685     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.17     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 8194     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1748     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.111    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 8340     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1872     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.0685   |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 8432     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1961     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 8562     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2083     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 8668     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2207     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 8748     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2310     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 8772     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2394     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 8817     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2468     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 8868     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2552     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 8904     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2622     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 8950     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2732     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 9001     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2807     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 9015     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2862     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 9057     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2942     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 9120     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3047     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 9157     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3115     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 9163     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3192     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 9178     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3264     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 9320     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3462     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 9340     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3517     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 9404     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3641     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 9444     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3750     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 9401     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3822     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 9417     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3888     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 9404     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3952     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 9440     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4056     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 9443     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4119     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 9487     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4212     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 9532     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4325     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 9565     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4449     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 9588     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4522     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 9611     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4598     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 9618     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4680     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 9654     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4795     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 9673     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4890     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 9684     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4978     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 9695     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5057     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 9715     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5144     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 9714     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5199     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 9725     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5280     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 9743     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5403     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 9770     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5497     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 9828     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5655     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 9857     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5753     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 9889     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5856     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 9897     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5946     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 9914     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6042     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 9930     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6125     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 9947     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6246     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 9942     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6296     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 9964     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6392     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 9972     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6463     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 9960     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6522     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 9980     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6627     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 9987     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6700     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 9998     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6798     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 9982     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6871     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 9991     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6930     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 9958     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7017     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 9966     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7084     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 9962     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7150     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 9989     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7261     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 9956     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7336     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 9945     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7467     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 9950     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7558     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 9960     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7667     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 9978     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7756     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 9972     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7837     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 9990     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7936     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 9974     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8026     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 9985     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8103     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 9978     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8178     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 9994     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8264     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 10009    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8375     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 10021    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8460     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 10021    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8531     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 10033    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8621     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 10029    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8700     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 10061    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8871     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 10063    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8950     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 10075    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9042     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 10092    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9151     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 10100    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9269     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 10111    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9356     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 10103    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9420     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 10118    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9535     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 10116    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9593     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 10116    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9667     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 10122    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9738     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 10120    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9806     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 10123    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9868     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 10129    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9953     |
# ----------------------------------
# Eval num_timesteps=10000, episode_reward=9.20 +/- 0.75
# Episode length: 9.20 +/- 0.75
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 9.2      |
# |    mean_reward      | 9.2      |
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    total timesteps  | 10000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 10004    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10048    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 10013    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10135    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 10017    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10197    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 10021    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10264    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 10018    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10335    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 10018    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10431    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 10012    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10503    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 10000    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10562    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 9991     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10641    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 9999     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10730    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 10002    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10822    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 10020    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10946    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 10040    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11092    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 10049    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11176    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 10057    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11253    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 10074    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11365    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 10069    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11447    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 10080    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11559    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 10085    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11650    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 10093    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11743    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 10101    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11845    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 10106    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11927    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 10107    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12007    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 10118    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12110    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 10126    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12210    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 10129    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12304    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 10143    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12428    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 10153    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12533    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 10156    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12617    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 10155    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12694    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 10159    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12764    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 10159    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12822    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 10157    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12940    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 10160    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13019    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 10161    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13095    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 10169    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13202    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 10175    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13283    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 10168    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13383    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 10171    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13471    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 10170    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13553    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 10176    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13665    |
# ----------------------------------
# ...
# |    fps              | 10265    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15537    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 10269    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15641    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 704      |
# |    fps              | 10272    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15714    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 708      |
# |    fps              | 10274    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15793    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 712      |
# |    fps              | 10278    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15896    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 716      |
# |    fps              | 10277    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15975    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 10281    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16064    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 10280    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16131    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 10291    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16244    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 10291    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16318    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 10297    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16395    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 10305    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16494    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 744      |
# |    fps              | 10315    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16609    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 748      |
# |    fps              | 10313    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16688    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 752      |
# |    fps              | 10319    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16771    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 756      |
# |    fps              | 10329    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16880    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 10332    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16958    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 764      |
# |    fps              | 10329    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17019    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 768      |
# |    fps              | 10330    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17099    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 772      |
# |    fps              | 10334    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17180    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 776      |
# |    fps              | 10332    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17249    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 10336    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17325    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 784      |
# |    fps              | 10336    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17398    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 788      |
# |    fps              | 10337    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17457    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 10343    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17557    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 796      |
# |    fps              | 10347    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17658    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 10353    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17763    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 804      |
# |    fps              | 10355    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17823    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 808      |
# |    fps              | 10362    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17973    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 812      |
# |    fps              | 10364    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18063    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 10372    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18240    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 10376    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18332    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 824      |
# |    fps              | 10384    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18457    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 10390    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18558    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 832      |
# |    fps              | 10393    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18636    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 836      |
# |    fps              | 10390    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18692    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 10396    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18792    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 844      |
# |    fps              | 10400    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18898    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 848      |
# |    fps              | 10406    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19009    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 852      |
# |    fps              | 10408    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19082    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 856      |
# |    fps              | 10417    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19209    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 10417    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 864      |
# |    fps              | 10420    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 868      |
# |    fps              | 10421    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19441    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 872      |
# |    fps              | 10428    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19566    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 876      |
# |    fps              | 10426    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19648    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 10425    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19720    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 884      |
# |    fps              | 10422    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19798    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 888      |
# |    fps              | 10427    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19902    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 892      |
# |    fps              | 10428    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19983    |
# ----------------------------------
# Eval num_timesteps=20000, episode_reward=9.60 +/- 0.80
# Episode length: 9.60 +/- 0.80
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 9.6      |
# |    mean_reward      | 9.6      |
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    total timesteps  | 20000    |
# ----------------------------------

# %%
dqn_path = os.path.join('Training', 'Saved Models', 'DQN_model')

# %%
model.save(dqn_path)

# %%
model = DQN.load(dqn_path, env=env)

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# (9.1, 0.7000000000000001)

# %%
env.close()

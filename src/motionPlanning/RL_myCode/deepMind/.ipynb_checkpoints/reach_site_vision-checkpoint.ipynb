# %%
# Move the end effector to a target location in 3D space.

# %%
from dm_control import manipulation

# %%
# print('\n'.join(manipulation.ALL))
# print('\n'.join(manipulation.get_environments_by_tag('vision')))

# %%
env = manipulation.load('reach_site_vision', seed=100)
action_spec = env.action_spec()

# %% [markdown]
# ## Making Video

# %%
import numpy as np
from PIL import Image
import subprocess

# %%
time_step = env.reset()
time_step_counter = 0
subprocess.call(['rm', '-rf', 'frames'])
subprocess.call(['mkdir', '-p', 'frames'])
# Out:
# 0

# %%
while not time_step.last() and time_step_counter < 500:
    action = np.random.uniform(action_spec.minimum,
                               action_spec.maximum,
                               size=action_spec.shape)
    time_step = env.step(action)
    
    image_data = env.physics.render(height=400, width=480, camera_id='front_close')
    img = Image.fromarray(image_data, 'RGB')
    img.save('frames/frame-%.10d.png' % time_step_counter)
    
    time_step_counter += 1
    print(time_step.reward, time_step.discount, time_step.observation)
# Out:
# 1.606478088816359e-39 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.93859162, -0.34503011],
#         [ 0.37870978, -0.92551548],
#         [-0.96703886, -0.25462882],
#         [ 0.50013035,  0.86595013],
#         [-0.98940311, -0.14519462],
#         [-0.63659256,  0.77120031]]])), ('jaco_arm/joints_torque', array([[-2.30688235e-01,  2.41310725e+00, -1.77489284e+00,
#         -6.10417912e-01,  5.63194635e-02,  2.76978359e-05]])), ('jaco_arm/joints_vel', array([[-0.20723256,  0.18282994, -0.23619954, -0.09138117,  0.11642728,
#         -0.11619951]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.80889628, 0.79536147, 0.80894979]])), ('jaco_arm/jaco_hand/joints_vel', array([[ 0.30980957, -0.30583625,  0.31207915]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[-0.08675508, -0.03239975,  0.34419287]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.00371561,  0.99998904, -0.00284957,  0.9999403 ,  0.00368611,
#         -0.01028645, -0.01027583, -0.00288762, -0.99994303]]))])
# 2.344509079919305e-40 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.94064263, -0.33939865],
#         [ 0.36939603, -0.92927207],
#         [-0.96494282, -0.26246021],
#         [ 0.49965192,  0.86622627],
#         [-0.99040442, -0.13819945],
#         [-0.63777892,  0.77021948]]])), ('jaco_arm/joints_torque', array([[ 1.95506236e-01,  2.09526044e+00, -1.52564626e+00,
#         -3.99131992e-01,  6.88357032e-02,  3.42269577e-04]])), ('jaco_arm/joints_vel', array([[-0.13880513,  0.27264058, -0.19713716,  0.04829986,  0.23114199,
#          0.02244512]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.81177898, 0.79154395, 0.81188419]])), ('jaco_arm/jaco_hand/joints_vel', array([[-0.10521175, -0.00617692, -0.10428356]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[-0.08573304, -0.03554027,  0.35087628]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.0117836 ,  0.99984467, -0.01310629,  0.99943898,  0.01136584,
#         -0.03150479, -0.03135093, -0.01347017, -0.99941767]]))])
# 3.042188157255408e-40 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.94435332, -0.32893282],
#         [ 0.36239425, -0.93202489],
#         [-0.96468702, -0.26339883],
#         [ 0.49926444,  0.86644966],
#         [-0.99122265, -0.13220306],
#         [-0.63896809,  0.76923324]]])), ('jaco_arm/joints_torque', array([[-0.81490443,  1.98024012, -1.27933273, -0.51964419, -0.1590275 ,
#          0.01026466]])), ('jaco_arm/joints_vel', array([[-0.39610205,  0.16888853,  0.12511673, -0.05933765,  0.07915154,
#         -0.09386552]])), ('jaco_arm/jaco_hand/joints_pos', array([[0
1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.9561725 , -0.29280394],
#         [ 0.37144964, -0.9284531 ],
#         [-0.96162419, -0.27437002],
#         [ 0.48099537,  0.87672314],
#         [-0.99983002, -0.01843736],
#         [-0.68084181,  0.73243049]]])), ('jaco_arm/joints_torque', array([[ 0.94545932,  2.43709971, -1.76278735, -0.40024721,  0.1698637 ,
#         -0.01864678]])), ('jaco_arm/joints_vel', array([[ 0.24091513, -0.08384874, -0.40673987,  0.10040713,  0.05481028,
#         -0.058154  ]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.90597318, 0.94194379, 0.84448771]])), ('jaco_arm/jaco_hand/joints_vel', array([[ 0.02629549,  0.48470147, -0.03278428]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[-0.07738898, -0.06205889,  0.35584063]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.06284823,  0.9956905 , -0.06819484,  0.99119785,  0.05429497,
#         -0.12074299, -0.11652001, -0.07518306, -0.99033863]]))])
# 8.772471571656004e-40 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.95517308, -0.29604793],
#         [ 0.37049587, -0.92883411],
#         [-0.95918079, -0.2827936 ],
#         [ 0.48484442,  0.87460042],
#         [-0.9999055 , -0.01374707],
#         [-0.68056199,  0.73269051]]])), ('jaco_arm/joints_torque', array([[-1.06372953,  2.27826713, -1.46788438, -0.61329394, -0.10914284,
#          0.01840794]])), ('jaco_arm/joints_vel', array([[-0.04765569,  0.12018911, -0.05146431,  0.11034946,  0.17366429,
#          0.06499212]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.91369147, 0.95041048, 0.85018187]])), ('jaco_arm/jaco_hand/joints_vel', array([[0.32945519, 0.00158414, 0.28583374]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[-0.08149065, -0.06448994,  0.35884684]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.06368681,  0.99488992, -0.07834568,  0.98990876,  0.05301937,
#         -0.1314138 , -0.12658843, -0.0859244 , -0.98822688]]))])
# 1.6176950615187877e-40 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.95441644, -0.29847824],
#         [ 0.37253913, -0.92801649],
#         [-0.95709305, -0.28978076],
#         [ 0.48608935,  0.87390912],
#         [-0.9999898 , -0.00451755],
#         [-0.67852066,  0.73458131]]])), ('jaco_arm/joints_torque', array([[ 0.13299274,  1.60913838, -1.51464653, -0.3941768 ,  0.25221897,
#         -0.00688047]])), ('jaco_arm/joints_vel', array([[ 0.10936016, -0.20951954, -0.30071102, -0.02135242,  0.28280887,
#          0.06978626]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.93178749, 0.94372716, 0.85232813]])), ('jaco_arm/jaco_hand/joints_vel', array([[ 0.55299425, -0.30520994, -0.11930408]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[-0.08505793, -0.06764608,  0.36021102]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.06947651,  0.99378481, -0.08697562,  0.98834121,  0.05673015,
#         -0.14129173, -0.13547943, -0.09577804, -0.98613989]]))])
# 1.1104133828603215e-40 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.95413305, -0.29938291],
#         [ 0.37584447, -0.92668276],
#         [-0.95574378, -0.29420032],
#         [ 0.48350201,  0.87534325],
#         [-0.99999346,  0.00361639],
#         [-0.67854108,  0.73456246]]])), ('jaco_arm/joints_torque', array([[-2.51589539e-01,  2.28511889e+00, -1.47961225e+00,
#         -4.58939311e-01, -3.78387006e-02, -9.87170799e-04]])), ('jaco_arm/joints_vel', array([[ 0.00115373,  0.01256663,  0.04355528, -0.12292078,  0.14086514,
#         -0.05697129]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.95759577, 0.94102952, 0.85520671]])), ('jaco_arm/jaco_hand/joints_vel', array([[0.72080385, 0.10980037, 0.22479411]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[-0.08640814, -0.07054534,  0.36038303]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.07237433,  0.99335449, -0.08949202,  0.98724031,  0.0585894 ,
#         -0.14806705, -0.14183979, -0.09906639, -0.98491996]]))])
# 1.0674034863732366e-41 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.95243697, -0.30473566],
#         [ 0.37177392, -0.9283233 ],
#         [-0.95540165, -0.29530948],
#         [ 0.48087206,  0.87679077],
#         [-0.99993317,  0.01156067],
#         [-0.67822136,  0.73485766]]])), ('jaco_arm/joints_torque', array([[ 1.04111829,  2.36504354, -1.69684756, -0.27526437,  0.21522667,
#         -0.01699691]])), ('jaco_arm/joints_vel', array([[ 0.26685099,  0.19880525, -0.04803183, -0.0661688 ,  0.25127147,
#          0.06662897]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.974067  , 0.95164122, 0.86975839]])), ('jaco_arm/jaco_hand/joints_vel', array([[0.15868648, 0.3924789 , 0.47752124]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[-0.0894133 , -0.0713758 ,  0.36323661]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.0712194 ,  0.99302909, -0.09392027,  0.98578353,  0.05570732,
#         -0.15851663, -0.15217958, -0.10387451, -0.98287917]]))])
# 3.949990003663402e-43 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.95109814, -0.30888885],
#         [ 0.36053274, -0.93274656],
#         [-0.95679625, -0.29075926],
#         [ 0.48124808,  0.87658444],
#         [-0.99971713,  0.02378376],
#         [-0.67446998,  0.73830228]]])), ('jaco_arm/joints_torque', array([[-1.01618601,  2.1438347 , -1.38569224, -0.5535703 , -0.07983639,
#          0.01607305]])), ('jaco_arm/joints_vel', array([[-0.02584848,  0.38860152,  0.2697964 ,  0.07403451,  0.33080189,
#          0.18224486]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.98601639, 0.95710968, 0.87800048]])), ('jaco_arm/jaco_hand/joints_vel', array([[ 0.38147088, -0.05538555, -0.00251374]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[-0.09256607, -0.07021364,  0.36772149]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.07920465,  0.99137233, -0.10443909,  0.98319136,  0.06039979,
#         -0.17229802, -0.16450339, -0.11633042, -0.97949266]]))])
# 1.7588703122437142e-43 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.95312996, -0.3025612 ],
#         [ 0.35188063, -0.93604488],
#         [-0.95818359, -0.28615418],
#         [ 0.48160431,  0.87638878],
#         [-0.99922527,  0.03935546],
#         [-0.67150216,  0.7410026 ]]])), ('jaco_arm/joints_torque', array([[-1.03411325,  2.16923927, -1.706561  , -0.69021496,  0.15728881,
#          0.00537303]])), ('jaco_arm/joints_vel', array([[-0.29302862,  0.16054871, -0.00582688, -0.03824774,  0.4427515 ,
#          0.02678593]])), ('jaco_arm/jaco_hand/joints_pos', array([[1.00586553, 0.96206612, 0.88478165]])), ('jaco_arm/jaco_hand/joints_vel', array([[0.59034383, 0.27081315, 0.31050697]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[-0.09105159, -0.0707578 ,  0.37097526]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.09872871,  0.98856051, -0.11402086,  0.97946123,  0.07629264,
#         -0.18664175, -0.17580771, -0.1301059 , -0.97578896]]))])
# 8.686110865018153e-44 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.95472693, -0.29748359],
#         [ 0.34193585, -0.9397233 ],
#         [-0.960016  , -0.27994515],
#         [ 0.47820213,  0.87824981],
#         [-0.99855526,  0.05373443],
#         [-0.6688944 ,  0.74335744]]])), ('jaco_arm/joints_torque', array([[ 0.91070324,  2.25330751, -1.48765533, -0.22402546,  0.07765589,
#         -0.01353868]])), ('jaco_arm/joints_vel', array([[ 0.00500951,  0.35982327,  0.31352093, -0.14989836,  0.28490805,
#          0.14307149]])), ('jaco_arm/jaco_hand/joints_pos', array([[1.03296683, 0.96371115, 0.90223839]])), ('jaco_arm/jaco_hand/joints_vel', array([[ 0.74891104, -0.13053219,  0.53957103]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[-0.08871088, -0.0707838 ,  0.37458574]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.11478055,  0.98625018, -0.11889496,  0.97548691,  0.0892809 ,
#         -0.20113233, -0.18775174, -0.13906656, -0.97232185]]))])
# 1.5526958782670263e-43 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.95632531, -0.29230445],
#         [ 0.33547859, -0.94204783],
#         [-0.96180772, -0.27372598],
#         [ 0.47108771,  0.88208637],
#         [-0.99789598,  0.06483522],
#         [-0.66702408,  0.74503616]]])), ('jaco_arm/joints_torque', array([[-1.00793667,  1.58076151, -1.51406569, -0.60687859,  0.18503834,
#          0.00486002]])), ('jaco_arm/joints_vel', array([[-0.26267005,  0.00679294,  0.02826513, -0.24923997,  0.27767137,
#         -0.00233103]])), ('jaco_arm/jaco_hand/joints_pos', array([[1.06542956, 0.95250112, 0.91258205]])), ('jaco_arm/jaco_hand/joints_vel', array([[ 0.86288154, -0.40288388,  0.03752136]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[-0.08491854, -0.07103791,  0.37658786]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.12680479,  0.9850273 , -0.11679799,  0.97227575,  0.1001056 ,
#         -0.21132613, -0.19646987, -0.14035702, -0.97041202]]))])
# 8.562968681469711e-42 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
# ...
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.98176478,  0.19009974],
#         [ 0.93118887, -0.36453709],
#         [-0.99997193,  0.00749287],
#         [ 0.29075258,  0.95679827],
#         [-0.91593135, -0.40133497],
#         [-0.64229876,  0.76645437]]])), ('jaco_arm/joints_torque', array([[-0.79459777,  1.97396887, -0.34981196, -0.2777257 , -0.3394196 ,
#          0.0163959 ]])), ('jaco_arm/joints_vel', array([[-0.16743652, -0.13963621, -0.04632933,  0.02751826, -0.05972957,
#          0.18959119]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.80364844, 0.6512301 , 0.24819583]])), ('jaco_arm/jaco_hand/joints_vel', array([[ 0.24210502, -0.36842962, -0.86035426]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[0.20306118, 0.17551577, 0.08328422]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.28960184,  0.94119091,  0.17404152,  0.32734385, -0.0734765 ,
#          0.94204416,  0.89943136,  0.32978914, -0.28681413]]))])
# 4.49796738791697e-25 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 9.79563583e-01,  2.01134746e-01],
#         [ 9.32587817e-01, -3.60943159e-01],
#         [-9.99999996e-01, -8.36788895e-05],
#         [ 2.89748631e-01,  9.57102780e-01],
#         [-9.14098398e-01, -4.05492441e-01],
#         [-6.39001223e-01,  7.69205718e-01]]])), ('jaco_arm/joints_torque', array([[-0.11076276,  2.39245297, -0.80248433, -0.46582711, -0.44919086,
#          0.02033082]])), ('jaco_arm/joints_vel', array([[-0.33258884, -0.08761188, -0.31907941, -0.07508125, -0.16293675,
#          0.03302784]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.80505719, 0.64648779, 0.21185415]])), ('jaco_arm/jaco_hand/joints_vel', array([[-0.06897721,  0.068335  , -0.94793164]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[0.20669438, 0.17600781, 0.08223028]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.2962733 ,  0.94042975,  0.16677534,  0.32531012, -0.06481336,
#          0.94338357,  0.89799524,  0.33375307, -0.28672885]]))])
# 1.3206077716848642e-25 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.97753302,  0.21078236],
#         [ 0.93636501, -0.35102788],
#         [-0.99998035, -0.00626831],
#         [ 0.28858471,  0.95745437],
#         [-0.91049515, -0.41351975],
#         [-0.63989189,  0.76846495]]])), ('jaco_arm/joints_torque', array([[-2.42255274e-01,  1.85790832e+00,  6.76377699e-01,
#          8.25949595e-02, -3.57001595e-01,  6.03543674e-04]])), ('jaco_arm/joints_vel', array([[-0.2248619 , -0.42610397, -0.0117095 , -0.02171156, -0.27111054,
#         -0.08404313]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.80956261, 0.64195258, 0.17244755]])), ('jaco_arm/jaco_hand/joints_vel', array([[ 0.26128418, -0.26228636, -1.01570101]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[0.21020306, 0.17804917, 0.08022816]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.29419633,  0.94183493,  0.16246688,  0.31378585, -0.06538351,
#          0.94723991,  0.90276628,  0.32965431, -0.27629888]]))])
# 1.7482909272795922e-26 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.97733872,  0.21168143],
#         [ 0.94129336, -0.33758972],
#         [-0.99999858, -0.00168574],
#         [ 0.2845475 ,  0.95866194],
#         [-0.9067989 , -0.42156347],
#         [-0.63973981,  0.76859156]]])), ('jaco_arm/joints_torque', array([[-2.79713504, -3.18695385,  2.88660104,  2.22805383,  1.2113228 ,
#         -1.19081106]])), ('jaco_arm/joints_vel', array([[ 0.22625768, -0.12011617,  0.17022792, -0.2416079 , -0.24675373,
#          0.11072909]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.81101155, 0.6260823 , 0.14718289]])), ('jaco_arm/jaco_hand/joints_vel', array([[-0.13143528, -0.50673463, -0.1684095 ]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[0.21157942, 0.18218366, 0.07881311]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.28778448,  0.94270279,  0.16879436,  0.29265759, -0.08125361,
#          0.95275883,  0.91188356,  0.32358816, -0.2525056 ]]))])
# 2.0543814333667972e-26 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.97948843,  0.20150042],
#         [ 0.94152149, -0.33695294],
#         [-0.99998459,  0.00555093],
#         [ 0.27854533,  0.96042308],
#         [-0.9016534 , -0.43245942],
#         [-0.63870431,  0.76945228]]])), ('jaco_arm/joints_torque', array([[ 0.12171714,  2.48618773, -0.43224764, -0.30026264, -0.48012136,
#          0.01540282]])), ('jaco_arm/joints_vel', array([[ 0.26673957,  0.06835531,  0.18270237, -0.07899505, -0.35047806,
#         -0.02660425]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.81361846, 0.60181551, 0.14805727]])), ('jaco_arm/jaco_hand/joints_vel', array([[ 0.22083883, -0.68853125,  0.05302483]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[0.21176476, 0.18190369, 0.0819543 ]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.28026599,  0.94091235,  0.19009187,  0.28300871, -0.10823336,
#          0.95299088,  0.91725517,  0.32088858, -0.23595227]]))])
# 2.814881312320125e-26 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.98050719,  0.19648318],
#         [ 0.94148907, -0.33704352],
#         [-0.9999788 ,  0.00651135],
#         [ 0.27844814,  0.96045127],
#         [-0.89505431, -0.44595715],
#         [-0.63765679,  0.7703206 ]]])), ('jaco_arm/joints_torque', array([[-0.03364075,  2.36650784, -0.68446555, -0.36714915, -0.4146949 ,
#          0.02142835]])), ('jaco_arm/joints_vel', array([[ 0.05555611, -0.01078215, -0.10968453,  0.05872456, -0.37910699,
#          0.08886955]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.82805699, 0.58641931, 0.14933689]])), ('jaco_arm/jaco_hand/joints_vel', array([[ 0.47594741, -0.13611309,  0.01602829]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[0.21229753, 0.18118092, 0.0846219 ]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.27452557,  0.94009118,  0.20214918,  0.27503907, -0.12467576,
#          0.95331499,  0.92140611,  0.31730826, -0.22433512]]))])
# 9.061436076497363e-26 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.97985504,  0.19971004],
#         [ 0.94042251, -0.3400081 ],
#         [-0.99999358, -0.00358368],
#         [ 0.27835531,  0.96047817],
#         [-0.88982113, -0.45630949],
#         [-0.63326906,  0.77393171]]])), ('jaco_arm/joints_torque', array([[-1.18282416,  2.5249806 , -0.84499844, -0.59095284, -0.52325239,
#          0.03840751]])), ('jaco_arm/joints_vel', array([[-0.20699759,  0.15969919, -0.38147829, -0.05083694, -0.20937539,
#          0.16679644]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.83628824, 0.57490585, 0.14959412]])), ('jaco_arm/jaco_hand/joints_vel', array([[-0.00167716, -0.41213373,  0.00102834]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[0.21509914, 0.17809496, 0.08615314]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.27904735,  0.9380929 ,  0.20521767,  0.27999576, -0.1249361 ,
#          0.95183683,  0.91855046,  0.32306762, -0.22779895]]))])
# 1.3091947113195535e-25 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.97757197,  0.2106016 ],
#         [ 0.93828048, -0.34587531],
#         [-0.99992398, -0.01233019],
#         [ 0.27451507,  0.9615828 ],
#         [-0.88496361, -0.46566018],
#         [-0.63063031,  0.77608338]]])), ('jaco_arm/joints_torque', array([[-0.13418173,  2.32747251, -0.17210199, -0.25710523, -0.45381403,
#          0.0134453 ]])), ('jaco_arm/joints_vel', array([[-0.29575689,  0.15507621, -0.10247852, -0.12027335, -0.3127674 ,
#          0.01516538]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.82952802, 0.56872914, 0.15213296]])), ('jaco_arm/jaco_hand/joints_vel', array([[-0.30603334,  0.0401465 ,  0.07710527]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[0.22061196, 0.17615224, 0.08876696]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.28464545,  0.93662752,  0.20422011,  0.28538989, -0.12057811,
#          0.95079626,  0.91516642,  0.32892218, -0.23298201]]))])

# %%
# convert frames to video
subprocess.call([
    'ffmpeg', '-framerate', '50', '-y', '-i', 'frames/frame-%010d.png', '-r', '30', '-pix_fmt', 'yuv420p', 'video_name.mp4'
])
# Out:
# 0

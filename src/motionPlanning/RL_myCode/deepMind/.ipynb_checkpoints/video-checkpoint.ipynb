# %%
# %config IPCompleter.use_jedi=False
# !pip install dm_control

# %%
from dm_control import suite
import numpy as np
from PIL import Image
import subprocess

# %%
# Main domains
# env = suite.load(domain_name='humanoid', task_name='run')
# env = suite.load(domain_name='manipulator', task_name='bring_ball')

# %%
# Additional domains
from dm_control import manipulation

# %%
env = manipulation.load('stack_3_bricks_vision', seed=42)
# Out:
# WARNING:absl:Pre-allocated contact buffer is full. Increase nconmax above 100. Time = 0.0000.
# WARNING:absl:Pre-allocated contact buffer is full. Increase nconmax above 100. Time = 0.0000.
# WARNING:absl:Physics state is invalid. Warning(s) raised: mjWARN_CONTACTFULL

# %%
action_spec = env.action_spec()
time_step = env.reset()
# Out:
# WARNING:absl:Pre-allocated contact buffer is full. Increase nconmax above 100. Time = 0.0000.
# WARNING:absl:Pre-allocated contact buffer is full. Increase nconmax above 100. Time = 0.0000.
# WARNING:absl:Physics state is invalid. Warning(s) raised: mjWARN_CONTACTFULL
# WARNING:absl:Pre-allocated contact buffer is full. Increase nconmax above 100. Time = 0.0000.

# %%
time_step_counter = 0

# %%
subprocess.call(['rm', '-rf', 'frames'])
subprocess.call(['mkdir', '-p', 'frames'])
# Out:
# 0

# %%
while not time_step.last() and time_step_counter < 500:
    action = np.random.uniform(action_spec.minimum,
                               action_spec.maximum,
                               size=action_spec.shape)
    time_step = env.step(action)
    
#     image_data = env.physics.render(height=400, width=480, camera_id='back')  # this is for humanoid
#     image_data = env.physics.render(height=400, width=480, camera_id='fixed')  # this is for manipulator
    image_data = env.physics.render(height=400, width=480, camera_id='front_close')  # this is for stack_3_bricks_vision
    
    img = Image.fromarray(image_data, 'RGB')
    img.save('frames/frame-%.10d.png' % time_step_counter)
    
    time_step_counter += 1
    print(time_step.reward, time_step.discount, time_step.observation)
# Out:
# 0.003351055550522102 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.97142544, -0.23734493],
#         [ 0.31199876, -0.95008251],
#         [-0.98787585, -0.15524598],
#         [ 0.4922254 ,  0.87046778],
#         [-0.99344429, -0.11431727],
#         [-0.73265319,  0.68060217]]])), ('jaco_arm/joints_torque', array([[ 1.01830582,  2.07251368, -1.67114022, -0.25199597,  0.22458614,
#         -0.01770164]])), ('jaco_arm/joints_vel', array([[ 0.26722738, -0.10237468, -0.24427603,  0.12080952,  0.11052377,
#          0.11634895]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.50741546, 0.50744646, 0.507433  ]])), ('jaco_arm/jaco_hand/joints_vel', array([[0.31136216, 0.31269553, 0.31207986]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[-0.03045264, -0.01055531,  0.3461653 ]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[ 0.00159349,  0.9999898 , -0.00422597,  0.99999516, -0.00160476,
#         -0.00266391, -0.00267066, -0.00422171, -0.99998752]]))])
# 0.003351055550523212 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.96742233, -0.25316798],
#         [ 0.31701604, -0.94842018],
#         [-0.98745864, -0.15787794],
#         [ 0.49853808,  0.8668678 ],
#         [-0.99418132, -0.10771956],
#         [-0.72780574,  0.68578335]]])), ('jaco_arm/joints_torque', array([[ 0.96959922,  1.89635814, -1.26952855, -0.04349936,  0.03596487,
#         -0.01426376]])), ('jaco_arm/joints_vel', array([[ 0.53552271, -0.13828856,  0.08528665,  0.23705038,  0.1959575 ,
#          0.23259792]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.51036977, 0.51040196, 0.5103577 ]])), ('jaco_arm/jaco_hand/joints_vel', array([[-0.10285543, -0.10395232, -0.1048354 ]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[-0
])), ('jaco_arm/jaco_hand/joints_pos', array([[0.46877294, 0.59307889, 0.52503597]])), ('jaco_arm/jaco_hand/joints_vel', array([[-0.05462786, -0.58711735, -0.67744098]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[-0.09643439, -0.02382425,  0.33569954]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[ 9.42501210e-04,  9.91224777e-01, -1.32183785e-01,
#          9.98729811e-01, -7.59211857e-03, -4.98108899e-02,
#         -5.03773432e-02, -1.31968940e-01, -9.89972890e-01]]))])
# 0.003351055550523232 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.95288104, -0.30334424],
#         [ 0.34087475, -0.94010872],
#         [-0.98484472, -0.17343837],
#         [ 0.54604845,  0.8377536 ],
#         [-0.99987717,  0.0156732 ],
#         [-0.73424377,  0.67888592]]])), ('jaco_arm/joints_torque', array([[-0.92992745,  2.20911093, -1.6815754 , -0.60918499,  0.09602862,
#          0.00430049]])), ('jaco_arm/joints_vel', array([[-0.31342367, -0.07692102, -0.3066445 ,  0.18236216,  0.00351668,
#         -0.02817515]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.46017495, 0.56621606, 0.49507848]])), ('jaco_arm/jaco_hand/joints_vel', array([[-0.34638592, -0.74078241, -0.80754925]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[-0.09576761, -0.02723326,  0.33518937]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.01045142,  0.99033068, -0.13833261,  0.99859382,  0.00314664,
#         -0.05291965, -0.05197267, -0.13869117, -0.98897098]]))])
# 0.003351055550523232 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.95799487, -0.28678533],
#         [ 0.33971799, -0.94052734],
#         [-0.98325302, -0.18224573],
#         [ 0.54969979,  0.83536228],
#         [-0.99985415,  0.01707875],
#         [-0.73666045,  0.6762628 ]]])), ('jaco_arm/joints_torque', array([[-0.28252818,  2.32688412, -1.6462619 , -0.4888319 ,  0.06201399,
#         -0.00628656]])), ('jaco_arm/joints_vel', array([[-0.49113884,  0.12277911, -0.20678904,  0.04204825,  0.04010721,
#         -0.14426346]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.4415556 , 0.54914048, 0.46063118]])), ('jaco_arm/jaco_hand/joints_vel', array([[-0.56298459, -0.16953882, -0.90495872]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[-0.09045901, -0.0314244 ,  0.33821895]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.02617789,  0.98907044, -0.14510128,  0.99775895,  0.01691035,
#         -0.06473887, -0.06157759, -0.14647082, -0.98729656]]))])
# 0.003351055550523232 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.9617109 , -0.27406595],
#         [ 0.33905738, -0.9407657 ],
#         [-0.98285441, -0.18438333],
#         [ 0.55307195,  0.8331335 ],
#         [-0.99977829,  0.02105655],
#         [-0.73838431,  0.67438017]]])), ('jaco_arm/joints_torque', array([[ 1.11828199e+00,  2.02031186e+00, -1.51689301e+00,
#         -1.29388197e-04,  2.16887004e-01, -2.32735458e-02]])), ('jaco_arm/joints_vel', array([[-0.18662217, -0.01246073,  0.0188762 ,  0.15548105,  0.15273042,
#          0.00163913]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.4305508 , 0.55055508, 0.43786224]])), ('jaco_arm/jaco_hand/joints_vel', array([[-0.04672265,  0.19420435, -0.29364947]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[-0.0864777 , -0.03351414,  0.33907805]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.04015897,  0.98772573, -0.15094745,  0.99703402,  0.02968599,
#         -0.07100644, -0.06565387, -0.15335128, -0.98598831]]))])
# 0.003351055550523232 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.96210796, -0.2726688 ],
#         [ 0.33554312, -0.94202485],
#         [-0.98419412, -0.17709303],
#         [ 0.55559936,  0.83145015],
#         [-0.99971377,  0.02392424],
#         [-0.73669041,  0.67623017]]])), ('jaco_arm/joints_torque', array([[ 0.14814726,  2.23407104, -1.42556505, -0.33236442, -0.04418916,
#         -0.00304898]])), ('jaco_arm/joints_vel', array([[0.06373336, 0.18906388, 0.33581539, 0.00985831, 0.00481262,
#         0.11791397]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.42224542, 0.5499115 , 0.43554597]])), ('jaco_arm/jaco_hand/joints_vel', array([[-0.33950094, -0.17644848,  0.11807183]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[-0.08630148, -0.03125335,  0.33840895]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.04638875,  0.98694402, -0.15423873,  0.99697122,  0.03609427,
#         -0.06888819, -0.06242165, -0.15696721, -0.98562916]]))])
# 0.003351055550523232 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
# ...
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.9999419 ,  0.01077918],
#         [ 0.72391132, -0.68989304],
#         [-0.99708517,  0.07629662],
#         [ 0.22877507,  0.97347931],
#         [-0.99764878,  0.06853407],
#         [-0.67588485,  0.73700724]]])), ('jaco_arm/joints_torque', array([[-1.30941047,  2.42983236, -0.80003691, -0.54083333, -0.48570153,
#          0.02832957]])), ('jaco_arm/joints_vel', array([[ 0.11125065, -0.37438879,  0.04247328,  0.06267263,  0.1002642 ,
#          0.02448324]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.17926954, 1.11535979, 0.73496786]])), ('jaco_arm/jaco_hand/joints_vel', array([[-0.27499372, -0.19605836, -0.4676136 ]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[0.12507479, 0.06240959, 0.13268415]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.32580504,  0.92630553,  0.18923305,  0.82568514,  0.18128151,
#          0.53421069,  0.46053786,  0.33029545, -0.82389914]]))])
# 0.003351055550523232 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.99992689,  0.01209182],
#         [ 0.73108171, -0.68228992],
#         [-0.99709347,  0.07618801],
#         [ 0.23392338,  0.97225503],
#         [-0.99756837,  0.0696946 ],
#         [-0.67356742,  0.73912579]]])), ('jaco_arm/joints_torque', array([[-0.92335211,  2.46976987, -1.07678048, -0.53372009, -0.41089694,
#          0.01930609]])), ('jaco_arm/joints_vel', array([[-0.15389707, -0.15838004, -0.01083137,  0.19469146, -0.0257182 ,
#          0.10453089]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.1775794 , 1.11592972, 0.71212233]])), ('jaco_arm/jaco_hand/joints_vel', array([[ 0.13188064,  0.17432873, -0.65606604]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[0.12410561, 0.06445052, 0.1286022 ]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.3319875 ,  0.92535952,  0.18301384,  0.81879642,  0.18636554,
#          0.54299199,  0.46835533,  0.33011763, -0.81955209]]))])
# 0.003351055550523232 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.99971779,  0.02375566],
#         [ 0.74014496, -0.67244736],
#         [-0.9971044 ,  0.07604478],
#         [ 0.24402315,  0.96976941],
#         [-0.99779284,  0.06640369],
#         [-0.67272955,  0.73988847]]])), ('jaco_arm/joints_torque', array([[-0.90668544,  2.05122449, -0.71732334, -0.36194163, -0.33906875,
#          0.01158707]])), ('jaco_arm/joints_vel', array([[-0.41106616, -0.48292265, -0.00215097,  0.31918631, -0.13378842,
#         -0.03112596]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.1751245 , 1.12865466, 0.68278175]])), ('jaco_arm/jaco_hand/joints_vel', array([[-0.21386273,  0.43590771, -0.79692848]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[0.12576675, 0.06928952, 0.1236968 ]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.34477102,  0.92354186,  0.16793864,  0.80488458,  0.19879916,
#          0.55914193,  0.48300492,  0.32794715, -0.81188479]]))])
# 0.003351055550523232 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.99936382,  0.03566456],
#         [ 0.75000013, -0.66143768],
#         [-0.99703829,  0.07690676],
#         [ 0.25339665,  0.96736247],
#         [-0.99792716,  0.06435357],
#         [-0.67544888,  0.73740682]]])), ('jaco_arm/joints_torque', array([[ 0.03159296,  2.48178821, -1.14750915, -0.48773201, -0.3459577 ,
#          0.01062941]])), ('jaco_arm/joints_vel', array([[-0.25868056, -0.2670137 ,  0.0256905 ,  0.17322914,  0.01484467,
#         -0.14719883]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.17530031, 1.13546904, 0.66372652]])), ('jaco_arm/jaco_hand/joints_vel', array([[ 0.16989481, -0.03092429, -0.21370804]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[0.12747053, 0.07457568, 0.11825502]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.35313138,  0.92306366,  0.1524851 ,  0.79072191,  0.20735175,
#          0.57598968,  0.50005709,  0.32397334, -0.80310907]]))])
# 0.003351055550523232 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.99877212,  0.04954046],
#         [ 0.7539999 , -0.65687453],
#         [-0.99662223,  0.08212262],
#         [ 0.26265714,  0.96488923],
#         [-0.99802873,  0.06275876],
#         [-0.68156791,  0.73175487]]])), ('jaco_arm/joints_torque', array([[ 0.04762062,  2.47431164, -1.04025821, -0.411924  , -0.3727575 ,
#          0.00865867]])), ('jaco_arm/joints_vel', array([[-0.37375127, -0.04847497,  0.16405957,  0.2995813 , -0.09036399,
#         -0.26343063]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.17399632, 1.14111875, 0.6533633 ]])), ('jaco_arm/jaco_hand/joints_vel', array([[-0.18852901,  0.28252032, -0.2687279 ]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[0.1296759 , 0.08053442, 0.11559359]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.35862401,  0.92358647,  0.13556126,  0.77882363,  0.21597835,
#          0.58888633,  0.51460914,  0.31676709, -0.79676599]]))])
# 0.003351055550523232 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.99830482,  0.05820206],
#         [ 0.75361802, -0.65731261],
#         [-0.99577966,  0.09177616],
#         [ 0.276586  ,  0.96098917],
#         [-0.99806316,  0.06220874],
#         [-0.68686318,  0.72678675]]])), ('jaco_arm/joints_torque', array([[ 1.29246049e+00,  2.26997720e+00, -9.78968418e-01,
#         -1.27875782e-01, -2.05969264e-01,  7.01202634e-05]])), ('jaco_arm/joints_vel', array([[-0.07504135,  0.03289778,  0.2595578 ,  0.41797493,  0.04610094,
#         -0.10741569]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.16083444, 1.14306247, 0.6517698 ]])), ('jaco_arm/jaco_hand/joints_vel', array([[-0.44426146, -0.12592876,  0.131425  ]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[0.1287309 , 0.08694454, 0.11462789]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.36276685,  0.92456624,  0.11652248,  0.76845116,  0.2260659 ,
#          0.59864599,  0.52714611,  0.30671075, -0.79249321]]))])
# 0.003351055550523232 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.99777084,  0.06673349],
#         [ 0.75032632, -0.66106763],
#         [-0.99538232,  0.09598978],
#         [ 0.28986716,  0.95706689],
#         [-0.99782393,  0.06593486],
#         [-0.69083207,  0.72301525]]])), ('jaco_arm/joints_torque', array([[-1.14196481,  2.47871497, -1.28222919, -0.66801597, -0.36284569,
#          0.02212126]])), ('jaco_arm/joints_vel', array([[-0.33901688,  0.20818299, -0.02535627,  0.28120359,  0.10718397,
#         -0.14126452]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.14629673, 1.13191633, 0.66311506]])), ('jaco_arm/jaco_hand/joints_vel', array([[-0.01661395, -0.4038306 ,  0.40823611]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[0.12759377, 0.08962607, 0.11471499]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.37009781,  0.92391963,  0.09695425,  0.76405324,  0.24335978,
#          0.59749365,  0.52844135,  0.2952093 , -0.79599071]]))])
# 0.003351055550523232 1.0 OrderedDict([('front_close', array([[[[ 35,  53,  71],
#          [ 35,  53,  71],
#          [ 35,  52,  71],
#          ...,
#          [ 35,  52,  71],
#          [ 35,  53,  71],
#          [ 35,  53,  71]],
#
#         [[ 35,  53,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  53,  70]],
#
#         [[ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          ...,
#          [ 35,  52,  70],
#          [ 35,  52,  70],
#          [ 35,  52,  70]],
#
#         ...,
#
#         [[ 30,  61,  91],
#          [ 30,  61,  91],
#          [ 30,  61,  92],
#          ...,
#          [ 61,  91, 122],
#          [ 61,  91, 121],
#          [ 60,  90, 121]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 122],
#          [ 60,  90, 121],
#          [ 60,  90, 120]],
#
#         [[ 30,  60,  90],
#          [ 30,  61,  91],
#          [ 30,  61,  91],
#          ...,
#          [ 61,  91, 121],
#          [ 60,  90, 121],
#          [ 60,  90, 120]]]], dtype=uint8)), ('jaco_arm/joints_pos', array([[[ 0.99635189,  0.08533995],
#         [ 0.74984775, -0.66161042],
#         [-0.99594181,  0.08999952],
#         [ 0.30313648,  0.95294715],
#         [-0.99735041,  0.07274722],
#         [-0.6927446 ,  0.721183  ]]])), ('jaco_arm/joints_torque', array([[-0.16985568,  1.84221764, -0.65424768, -0.20100115, -0.22495253,
#          0.00698593]])), ('jaco_arm/joints_vel', array([[-0.53974669, -0.1452511 , -0.21488013,  0.40605597,  0.22824906,
#         -0.02609906]])), ('jaco_arm/jaco_hand/joints_pos', array([[0.15272876, 1.12063537, 0.68393105]])), ('jaco_arm/jaco_hand/joints_vel', array([[ 0.30251342, -0.25467041,  0.61204814]])), ('jaco_arm/jaco_hand/pinch_site_pos', array([[0.12953905, 0.089391  , 0.11323009]])), ('jaco_arm/jaco_hand/pinch_site_rmat', array([[-0.3892069 ,  0.91843261,  0.07070742,  0.75879233,  0.27614112,
#          0.58989853,  0.52225682,  0.28324482, -0.80437565]]))])

# %%
# convert frames to video
subprocess.call([
    'ffmpeg', '-framerate', '50', '-y', '-i', 'frames/frame-%010d.png', '-r', '30', '-pix_fmt', 'yuv420p', 'video_name.mp4'
])
# Out:
# 0

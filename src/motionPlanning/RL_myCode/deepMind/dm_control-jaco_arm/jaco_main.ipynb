# %%
# !python main.py --domain jaco --task easy  # simplified version
# !python main.py --domain jaco --task reacher_easy  # complete version

# %%
# %env JOBLIB_TEMP_FOLDER=/tmp
# Out:
# env: JOBLIB_TEMP_FOLDER=/tmp

# %%
# !python main.py --domain jaco --task easy --policy TD3 --seed 100 --device 'cuda:0' --exp_name 'jaco_relative_reacher'
# Out:
# ---------------------------------------
# Policy: TD3 Domain: jaco, Task: easy, Seed: 100
# ---------------------------------------
# storing results in: results/jaco_relative_reacher00
# ---------------------------------------
# writing data files results/jaco_relative_reacher00/jaco_relative_reacher_TD3_jaco_00100_0000000000
# finished writing files in 0.8335819244384766 secs
# EPISODE 0 END: Ep R: 0.0 Ep Time: 5.254843711853027 Ep Steps:19999 Total Steps: 19999
# Total T: 19999 Episode Num: 0 Reward: 0.0
# ---------------------------------------
# EPISODE 1 END: Ep R: 0.0 Ep Time: 62.499022245407104 Ep Steps:20000 Total Steps: 39999
# Total T: 39999 Episode Num: 1 Reward: 0.0
# ---------------------------------------
# ---------------------------------------
# writing data files results/jaco_relative_reacher00/jaco_relative_reacher_TD3_jaco_00100_0000050000
# finished writing files in 0.8545236587524414 secs
# ...

# %%
# !python main.py --domain jaco --task easy --policy TD3 --load_model results/jaco_relative_reacher00/ --plot_action_movie --camera_view 'topview'
# Out:
# ---------------------------------------
# Policy: TD3 Domain: jaco, Task: easy, Seed: 0
# ---------------------------------------
# loading latest model from dir: results/jaco_relative_reacher00/
# TD3 loading results/jaco_relative_reacher00/jaco_relative_reacher_TD3_jaco_00100_0008050000.pt
# continuing in loaded directory
# results/jaco_relative_reacher00
# loading replay from: results/jaco_relative_reacher00/
# Traceback (most recent call last):
#   File "main.py", line 413, in <module>
#     train()
#   File "main.py", line 179, in train
#     replay_buffer = load_replay_buffer(load_replay_path=args.load_replay, load_model_path=args.load_model, kwargs=kwargs, seed=args.seed)
#   File "main.py", line 163, in load_replay_buffer
#     replay_buffer = pickle.load(open(load_replay_path, 'rb'))
# IsADirectoryError: [Errno 21] Is a directory: 'results/jaco_relative_reacher00/'
